# %%
import pandas as pd
import zipfile
# Out:
# {1: 'Teste1', 2: 'Teste1', 3: 'Teste1', 4: 'Teste1', 5: 'Teste1', 6: 'Teste1', 7: 'Teste1'}
# ('t', 'e', 's', 't', 'e')
# [1, 2, 3, 4, 5]
# teste

# %%
import pandas as pd

print("Executou sporra")
